# %%
import os

###################################################################################
# Check that these are the correct paths running (change if necessary)

# Finn's Laptop
studydir = '/mnt/s/Research/Projects/KPUM_NODDI/Data'
niftibasefolder = 'nifti' # nifti basefolder to go within studydir
codedir = os.path.join(studydir,'code/kpum_noddi')
codedir = os.path.join('/home/finn','Code/kpum_noddi')
datadirbasefolder = 'derivatives/dMRI_np'
protocol = 'NEW' # 'NEW'
datadirbasefolder = 'derivatives/dMRI_Testing7_dmri_pipeline'
protocol = 'ORIG' # 'NEW'
dPar = 1.7e-3 # value to use in NODDI estimation

# KPUM Workstation
#niftibasefolder = 'nifti' # nifti basefolder to go within studydir
studydir = '/mnt/e/Research/Projects/KPUM_NODDI/Data'
codedir = os.path.join('/home/radio/KPUM_NODDI','code/kpum_noddi')
datadirbasefolder = 'derivatives/dMRI_np' #'derivatives/dMRI_op'
protocol = 'NEW' # 'ORIG'
dPar = 1.7e-3


# Finn's Laptop
studydir = '/mnt/s/Research/Projects/KPUM_NODDI/Data'
niftibasefolder = 'nifti' # nifti basefolder to go within studydir
codedir = os.path.join(studydir,'code/kpum_noddi')
#codedir = os.path.join('/home/finn','Code/kpum_noddi')
datadirbasefolder = 'derivatives/dMRI_np'
protocol = 'NEW' # 'NEW'
datadirbasefolder = 'derivatives/dMRI_np_testing_ipynb_dmri_dtidkinoddi_pipeline'
protocol = 'NEW' # 'NEW'
dPar = 1.7e-3 # value to use in NODDI estimation

# tsv-files to keep track of in studydir/niftibasefolder
subjecttrackerpath = os.path.join(studydir, datadirbasefolder)
subjecttrackerfile = 'Subject_Tracker_for_dmri_dtidkinoddi_pipeline.tsv'

###################################################################################
# USER INPUT

# Participant details
subject = '035' # e.g. 035
session = 'MR1' # e.g. MR1

# %%
import os

# Define I/O folders and files
#niftifolder = os.path.join(studydir, niftibasefolder, os.path.join(f'sub-{subject}',f'ses-{session}'))
derivatives = os.path.join(studydir,datadirbasefolder)
datadir = os.path.join(derivatives, os.path.join(f'sub-{subject}',f'ses-{session}'))
if not os.path.exists(datadir): # then make this directory
    os.makedirs(datadir)
subjecttrackertsv = os.path.join(subjecttrackerpath, subjecttrackerfile)

def perform_process(processcall) :
    import os, subprocess
    # Perform the process given by the processcall by launching into terminal
    p=subprocess.Popen(processcall, stdout=subprocess.PIPE, shell=True)
    # Poll process.stdout to show stdout live
    while True:
        output = p.stdout.readline()
        if p.poll() is not None:
            break
        if output:
            print(output.strip().decode("utf-8"))
    rc = p.poll()

# %%
########################################
## START

import os 
import pandas as pd

#currdir = os.getcwd()
#os.chdir(studydir)

## Process to perform - dmri_dtidkinoddi_pipeline
process = 'dmri_dtidkinoddi_pipeline'
processfile = 'dmri_dtidkinoddi_pipeline.sh'
processfilepath = os.path.join(codedir,'shell', processfile)
processcall = f"bash {processfilepath} {subject} {session} {studydir} -derivatives {derivatives} -dPar {dPar} -p {protocol}"
perform_process(processcall)

#os.chdir(currdir)
# Out:
# KPUM NODDI dMRI pipeline
# ----------------------------
# Subject:       	035
# Session:        MR1
# Studydir:       /mnt/s/Research/Projects/KPUM_NODDI/Data
# MRI Protocol:   NEW
# Derivatives:    /mnt/s/Research/Projects/KPUM_NODDI/Data/derivatives/dMRI_np_testing_ipynb_dmri_dtidkinoddi_pipeline
# TSV file:       /mnt/s/Research/Projects/KPUM_NODDI/Data/derivatives/dMRI_np_testing_ipynb_dmri_dtidkinoddi_pipeline/Subject_Tracker_for_dmri_dtidkinoddi_pipeline.tsv
# dPar for NODDI: 0.0017
# Threads:        4
#
# CodeDir:        /mnt/s/Research/Projects/KPUM_NODDI/Data/code/kpum_noddi/shell
# /mnt/s/Research/Projects/KPUM_NODDI/Data/code/kpum_noddi/shell/dmri_dtidkinoddi_pipeline.sh   	035 MR1 /mnt/s/Research/Projects/KPUM_NODDI/Data -derivatives /mnt/s/Research/Projects/KPUM_NODDI/Data/derivatives/dMRI_np_testing_ipynb_dmri_dtidkinoddi_pipeline -dPar 0.0017 -p NEW
# ----------------------------
#
# START - dmri_prepare_pipeline
# Preparing for dMRI pipeline
# ----------------------------
# Subject:			035
# Session:			MR1
# Studydir:			/mnt/s/Research/Projects/KPUM_NODDI/Data
# Session file:		/mnt/s/Research/Projects/KPUM_NODDI/Data/nifti/sub-035/ses-MR1/session_QC.tsv
# Data directory:		/mnt/s/Research/Projects/KPUM_NODDI/Data/derivatives/dMRI_np_testing_ipynb_dmri_dtidkinoddi_pipeline/sub-035/ses-MR1
#
# Codedir:			/mnt/s/Research/Projects/KPUM_NODDI/Data/code/kpum_noddi/shell
# /mnt/s/Research/Projects/KPUM_NODDI/Data/code/kpum_noddi/shell/dmri_prepare_pipeline.sh		035 MR1 /mnt/s/Research/Projects/KPUM_NODDI/Data -s /mnt/s/Research/Projects/KPUM_NODDI/Data/nifti/sub-035/ses-MR1/session_QC.tsv -d /mnt/s/Research/Projects/KPUM_NODDI/Data/derivatives/dMRI_np_testing_ipynb_dmri_dtidkinoddi_pipeline/sub-035/ses-MR1
# ----------------------------
# Running dmri_prepare_pipeline on subject 035 and session MR1
#
# Transfer data in /mnt/s/Research/Projects/KPUM_NODDI/Data/nifti/sub-035/ses-MR1/session_QC.tsv which has qc_pass_fail = 1 or 0.5
# END - dmri_prepare_pipeline
# Runtime was 0.033 [min]
#
# START - dmri_preprocess
# dMRI preprocessing
# ----------------------------
# Subject:       	035
# Session:        MR1
# Studydir:		/mnt/s/Research/Projects/KPUM_NODDI/Data
# Session file:	/mnt/s/Research/Projects/KPUM_NODDI/Data/derivatives/dMRI_np_testing_ipynb_dmri_dtidkinoddi_pipeline/sub-035/ses-MR1/session_QC.tsv
# DWI (AP):
# MRI Protocol:	NEW
# Threads:		4
# DataDirectory:	/mnt/s/Research/Projects/KPUM_NODDI/Data/derivatives/dMRI_np_testing_ipynb_dmri_dtidkinoddi_pipeline/sub-035/ses-MR1
#
# Codedir:		/mnt/s/Research/Projects/KPUM_NODDI/Data/code/kpum_noddi/shell
# /mnt/s/Research/Projects/KPUM_NODDI/Data/code/kpum_noddi/shell/dmri_preprocess.sh   	035 MR1 /mnt/s/Research/Projects/KPUM_NODDI/Data -s /mnt/s/Research/Projects/KPUM_NODDI/Data/derivatives/dMRI_np_testing_ipynb_dmri_dtidkinoddi_pipeline/sub-035/ses-MR1/session_QC.tsv -d /mnt/s/Research/Projects/KPUM_NODDI/Data/derivatives/dMRI_np_testing_ipynb_dmri_dtidkinoddi_pipeline/sub-035/ses-MR1 -p NEW -t 4
# ----------------------------
# Running dmri_preprocess on subject 035 and session MR1
#
# Reading /mnt/s/Research/Projects/KPUM_NODDI/Data/derivatives/dMRI_np_testing_ipynb_dmri_dtidkinoddi_pipeline/sub-035/ses-MR1/session_QC.tsv and use entries to create relevant files
# No b0APPA.mif or pair of b0AP.mif and b0PA.mif are present to use with TOPUP
# 1. Do this by putting one good b0 from dir-AP_dwi and dir-PA_dwi into a file b0APPA.mif into /mnt/s/Research/Projects/KPUM_NODDI/Data/derivatives/dMRI_np_testing_ipynb_dmri_dtidkinoddi_pipeline/sub-035/ses-MR1/dwi/preproc/topup
# 2. The same b0 from dir-AP_dwi should be put 1st in the dir-AP_dwi dataset, as dwifslpreprocess will use the 1st b0 in dir-AP and replace the first b0 in b0APPA with
# 3. Run this script again.
#
# END - dmri_preprocess
# Runtime was 0.000 [min]
#
# START - dmri_dtidki
# DTI and DKI estimation
# ----------------------------
# Subject:       	035
# Session:        MR1
# Studydir:       /mnt/s/Research/Projects/KPUM_NODDI/Data
# DWI (AP):       No_image
# Mask:           /mnt/s/Research/Projects/KPUM_NODDI/Data/derivatives/dMRI_np_testing_ipynb_dmri_dtidkinoddi_pipeline/sub-035/ses-MR1/dwi/sub-035_ses-MR1_space-dwi_mask.mif
# Directory:      /mnt/s/Research/Projects/KPUM_NODDI/Data/derivatives/dMRI_np_testing_ipynb_dmri_dtidkinoddi_pipeline/sub-035/ses-MR1
# Threads:        4
#
# Codedir:        /mnt/s/Research/Projects/KPUM_NODDI/Data/code/kpum_noddi/shell
# /mnt/s/Research/Projects/KPUM_NODDI/Data/code/kpum_noddi/shell/dmri_dtidki.sh   	035 MR1 /mnt/s/Research/Projects/KPUM_NODDI/Data -d /mnt/s/Research/Projects/KPUM_NODDI/Data/derivatives/dMRI_np_testing_ipynb_dmri_dtidkinoddi_pipeline/sub-035/ses-MR1 -dwi /mnt/s/Research/Projects/KPUM_NODDI/Data/derivatives/dMRI_np_testing_ipynb_dmri_dtidkinoddi_pipeline/sub-035/ses-MR1/dwi/sub-035_ses-MR1_dir-AP_desc-preproc-inorm_dwi.mif -mask /mnt/s/Research/Projects/KPUM_NODDI/Data/derivatives/dMRI_np_testing_ipynb_dmri_dtidkinoddi_pipeline/sub-035/ses-MR1/dwi/sub-035_ses-MR1_space-dwi_mask.mif -t 4
# ----------------------------
# Running dmri_dtidki on subject 035 and session MR1
#
# Estimating DTI parameters using only b0 and b1000 shells
# mrconvert: [ERROR] unknown format for image "No_image"
# mrconvert: [ERROR] error opening image "No_image"
# mrconvert: [ERROR] failed to open key/value file "/mnt/s/Research/Projects/KPUM_NODDI/Data/derivatives/dMRI_np_testing_ipynb_dmri_dtidkinoddi_pipeline/sub-035/ses-MR1/dwi/sub-035_ses-MR1_space-dwi_mask.mif": No such file or directory
# mrconvert: [ERROR] error opening image "/mnt/s/Research/Projects/KPUM_NODDI/Data/derivatives/dMRI_np_testing_ipynb_dmri_dtidkinoddi_pipeline/sub-035/ses-MR1/dwi/sub-035_ses-MR1_space-dwi_mask.mif"
# dwiextract: [ERROR] failed to open key/value file "../sub-035_ses-MR1_dir-AP_desc-preproc-inorm_dwi.mif": No such file or directory
# dwiextract: [ERROR] error opening image "../sub-035_ses-MR1_dir-AP_desc-preproc-inorm_dwi.mif"
# dwi2tensor: [ERROR] no filename supplied to standard input (broken pipe?)
# dwi2tensor: [ERROR] error opening image "-"
# tensor2metric: [WARNING] existing output files will be overwritten
# tensor2metric: [ERROR] cannot stat file "sub-035_ses-MR1_dir-AP_desc-preproc-inorm_dwi_DT.nii": No such file or directory
# tensor2metric: [ERROR] cannot stat file "sub-035_ses-MR1_dir-AP_desc-preproc-inorm_dwi_DT.nii": No such file or directory
# tensor2metric: [ERROR] unknown format for image "sub-035_ses-MR1_dir-AP_desc-preproc-inorm_dwi_DT.nii"
# tensor2metric: [ERROR] error opening image "sub-035_ses-MR1_dir-AP_desc-preproc-inorm_dwi_DT.nii"
# mrcalc: [ERROR] cannot stat file "sub-035_ses-MR1_dir-AP_desc-preproc-inorm_dwi_MD.nii": No such file or directory
# mrcalc: [ERROR] cannot stat file "sub-035_ses-MR1_dir-AP_desc-preproc-inorm_dwi_MD.nii": No such file or directory
# mrcalc: [ERROR] Could not interpret string "sub-035_ses-MR1_dir-AP_desc-preproc-inorm_dwi_MD.nii" as either an image path or a numerical value
# mrcalc: [ERROR] As image:
# mrcalc: [ERROR] unknown format for image "sub-035_ses-MR1_dir-AP_desc-preproc-inorm_dwi_MD.nii"
# mrcalc: [ERROR] error opening image "sub-035_ses-MR1_dir-AP_desc-preproc-inorm_dwi_MD.nii"
# mrcalc: [ERROR] As numerical value:
# mrcalc: [ERROR] error converting string "sub-035_ses-MR1_dir-AP_desc-preproc-inorm_dwi_MD.nii" to complex float (no valid conversion)
# mrconvert: [ERROR] failed to open key/value file "sub-035_ses-MR1_dir-AP_desc-preproc-inorm_dwi.mif": No such file or directory
# mrconvert: [ERROR] error opening image "sub-035_ses-MR1_dir-AP_desc-preproc-inorm_dwi.mif"
# mrconvert: [ERROR] failed to open key/value file "sub-035_ses-MR1_space-dwi_mask.mif": No such file or directory
# mrconvert: [ERROR] error opening image "sub-035_ses-MR1_space-dwi_mask.mif"
# Traceback (most recent call last):
#   File "/home/finn/Software/miniconda3/envs/kpum_wsl/bin/dipy_fit_dki", line 7, in <module>
#     run_flow(ReconstDkiFlow())
#   File "/home/finn/Software/miniconda3/envs/kpum_wsl/lib/python3.10/site-packages/dipy/workflows/flow_runner.py", line 89, in run_flow
#     return flow.run(**args)
#   File "/home/finn/Software/miniconda3/envs/kpum_wsl/lib/python3.10/site-packages/dipy/workflows/reconst.py", line 821, in run
#     io_it = self.get_io_iterator()
#   File "/home/finn/Software/miniconda3/envs/kpum_wsl/lib/python3.10/site-packages/dipy/workflows/workflow.py", line 37, in get_io_iterator
#     io_it = io_iterator_(frame, self.run,
#   File "/home/finn/Software/miniconda3/envs/kpum_wsl/lib/python3.10/site-packages/dipy/workflows/multi_io.py", line 202, in io_iterator_
#     return io_iterator(inputs, out_dir, outputs, output_strategy, mix_names,
#   File "/home/finn/Software/miniconda3/envs/kpum_wsl/lib/python3.10/site-packages/dipy/workflows/multi_io.py", line 146, in io_iterator
#     io_it.set_inputs(*inputs)
#   File "/home/finn/Software/miniconda3/envs/kpum_wsl/lib/python3.10/site-packages/dipy/workflows/multi_io.py", line 222, in set_inputs
#     self.file_existence_check(args)
#   File "/home/finn/Software/miniconda3/envs/kpum_wsl/lib/python3.10/site-packages/dipy/workflows/multi_io.py", line 283, in file_existence_check
#     raise IOError('File not found: ' + path)
# OSError: File not found: ../sub-035_ses-MR1_dir-AP_desc-preproc-inorm_dwi.nii
# mrmath: [WARNING] existing output files will be overwritten
# mrmath: [ERROR] cannot stat file "sub-035_ses-MR1_dir-AP_desc-preproc-inorm_dwi_eval.nii": No such file or directory
# mrmath: [ERROR] cannot stat file "sub-035_ses-MR1_dir-AP_desc-preproc-inorm_dwi_eval.nii": No such file or directory
# mrmath: [ERROR] unknown format for image "sub-035_ses-MR1_dir-AP_desc-preproc-inorm_dwi_eval.nii"
# mrmath: [ERROR] error opening image "sub-035_ses-MR1_dir-AP_desc-preproc-inorm_dwi_eval.nii"
# END - dmri_dtidki
# Runtime was 0.033 [min]
#
# START - dmri_noddi
# NODDI estimation
# ----------------------------
# Subject:       	035
# Session:        MR1
# Studydir:       /mnt/s/Research/Projects/KPUM_NODDI/Data
# Derivatives:    /mnt/s/Research/Projects/KPUM_NODDI/Data/derivatives/dMRI_np_testing_ipynb_dmri_dtidkinoddi_pipeline
# Subjectdata:    sub-035/ses-MR1/dwi
# DWI (AP):       No_image
# Mask:           No_image
# dPar:           0.0017
# Threads:        4
#
# Codedir:        /mnt/s/Research/Projects/KPUM_NODDI/Data/code/kpum_noddi/shell
# /mnt/s/Research/Projects/KPUM_NODDI/Data/code/kpum_noddi/shell/dmri_noddi.sh   	035 MR1 /mnt/s/Research/Projects/KPUM_NODDI/Data -derivatives /mnt/s/Research/Projects/KPUM_NODDI/Data/derivatives/dMRI_np_testing_ipynb_dmri_dtidkinoddi_pipeline -subjectdata sub-035/ses-MR1/dwi -dwi /mnt/s/Research/Projects/KPUM_NODDI/Data/derivatives/dMRI_np_testing_ipynb_dmri_dtidkinoddi_pipeline/sub-035/ses-MR1/dwi/sub-035_ses-MR1_dir-AP_desc-preproc-inorm_dwi.mif -mask /mnt/s/Research/Projects/KPUM_NODDI/Data/derivatives/dMRI_np_testing_ipynb_dmri_dtidkinoddi_pipeline/sub-035/ses-MR1/dwi/sub-035_ses-MR1_space-dwi_mask.mif -dPar 0.0017 -t 4
# ----------------------------
# Running dmri_noddi on subject 035 and session MR1
# mrconvert: [ERROR] unknown format for image "No_image"
# mrconvert: [ERROR] error opening image "No_image"
# mrconvert: [ERROR] unknown format for image "No_image"
# mrconvert: [ERROR] error opening image "No_image"
# mrconvert: [ERROR] failed to open key/value file "sub-035_ses-MR1_dir-AP_desc-preproc-inorm_dwi.mif": No such file or directory
# mrconvert: [ERROR] error opening image "sub-035_ses-MR1_dir-AP_desc-preproc-inorm_dwi.mif"
# mrconvert: [ERROR] failed to open key/value file "sub-035_ses-MR1_space-dwi_mask.mif": No such file or directory
# mrconvert: [ERROR] error opening image "sub-035_ses-MR1_space-dwi_mask.mif"
# [ ERROR ] bvals file not exist:/mnt/s/Research/Projects/KPUM_NODDI/Data/derivatives/dMRI_np_testing_ipynb_dmri_dtidkinoddi_pipeline/sub-035/ses-MR1/dwi/sub-035_ses-MR1_dir-AP_desc-preproc-inorm_dwi.bval
#
# END - dmri_noddi
# Runtime was 0.033 [min]
#
# Finished - dmri_dtidkinoddi_pipeline.sh
# Included processes in dmri_dtidkinoddi_pipeline: 	dmri_prepare_pipeline	dmri_preprocess	dmri_dtidki	dmri_noddi
# Runtime was 0.117 [min]
#
# Book keeping by adding a line at the bottom of /mnt/s/Research/Projects/KPUM_NODDI/Data/derivatives/dMRI_np_testing_ipynb_dmri_dtidkinoddi_pipeline/Subject_Tracker_for_dmri_dtidkinoddi_pipeline.tsv
# /mnt/s/Research/Projects/KPUM_NODDI/Data/code/kpum_noddi/shell/dmri_noddi.sh: line 153: cd: /mnt/s/Research/Projects/KPUM_NODDI/Data/derivatives/dMRI_np_testing_ipynb_dmri_dtidkinoddi_pipeline/sub-035/ses-MR1/dwi/AMICO/NODDI: No such file or directory
# mv: cannot stat '*.nii.gz': No such file or directory
# gzip: sub-035_ses-MR1_dir-AP_desc-preproc-inorm_recon-NODDI-dPar-0p0017_*.nii.gz: No such file or directory
# mv: cannot stat 'AMICO/NODDI/*': No such file or directory
